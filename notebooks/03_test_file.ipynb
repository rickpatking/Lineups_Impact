# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/thunder_pacers_game7_stints.csv')

# %%
df
# Out:
#      game_id     team_id  period  start_num  end_num  duration_secs  \
# 0   42400407  1610612754       1          3       36          263.0
# 1   42400407  1610612754       1         36       42           23.0
# 2   42400407  1610612754       1         42       51           82.0
# 3   42400407  1610612754       1         51       59           41.0
# 4   42400407  1610612754       1         61      106          294.0
# 5   42400407  1610612754       1        106      113           16.0
# 6   42400407  1610612754       2        113      148          173.0
# 7   42400407  1610612754       2        151      159           33.0
# 8   42400407  1610612754       2        159      182          114.0
# 9   42400407  1610612754       2        183      218          192.0
# 10  42400407  1610612754       2        218      226           54.0
# 11  42400407  1610612754       2        226      238           51.0
# 12  42400407  1610612754       2        238      253           64.0
# ...
